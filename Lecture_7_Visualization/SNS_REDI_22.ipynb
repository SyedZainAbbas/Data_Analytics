# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
height = [62, 64, 69, 75, 66, 68, 65,71,76,73]
weight = [120, 136, 148, 175, 137, 165, 154, 172, 200, 187]
sns.scatterplot (x=height, y=weight)
plt.show()

# %%
gender = ["Female", "Female", "Female", "Female", "Female", "Male", "Male", "Male","Male"]
sns.countplot(x=gender)

# %%
tips = sns.load_dataset("tips")
print(tips.shape)
tips.head()
# Out:
# (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x="size", data=tips)

# %%
sns.scatterplot(x="total_bill", y ="tip", data=tips)

# %%
sns.scatterplot(x="total_bill", y ="tip", data=tips, hue="smoker")

# %%
sns.scatterplot(x="total_bill", y ="tip", data=tips, hue="smoker", hue_order=["No","Yes"])
plt.show()

# %%
hue_colors ={"Yes":"black", "No":"red"}
sns.scatterplot(x="total_bill", y ="tip", data=tips, hue="smoker", hue_order=["No","Yes"], palette=hue_colors)
plt.show()

# %%
hue_colors ={"Yes":"#808080", "No":"#00FF00"}
sns.scatterplot(x="total_bill", y ="tip", data=tips, hue="smoker", hue_order=["No","Yes"], palette=hue_colors)
plt.show()

# %%
sns.countplot(x="smoker", data=tips, hue="sex")
plt.show()

# %% [markdown]
# # relplot() vs. scatterplot()

# %% [markdown]
# relplot() lets you create subplots in a single figure

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter")

# %% [markdown]
# # Subplots in columns

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter", col="smoker")

# %% [markdown]
# # Subplots in rows

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter", row="smoker")

# %% [markdown]
# # Subplots in rows and columns

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter", col="smoker", row="time")

# %% [markdown]
# # Subgroups for days of the week

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter", col="day")

# %% [markdown]
# # Wrapping columns

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter", col="day", col_wrap=2)

# %% [markdown]
# # Ordering columns

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter", col="day", col_wrap=2, col_order=["Fri", "Thur", "Sat", "Sun"])

# %% [markdown]
# # Customizing scatter plots

# %% [markdown]
# We have seen:
# - Subplots (col and row)
# - Subgroups with color (hue)
#
# New customizations:
# - Subgroups with point size and style
# - Changing point transparency

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter", size="size")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Point size and hue

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter", size="size", hue="size")

# %% [markdown]
# # Subgroups with point style

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter", hue="smoker", style="smoker")

# %% [markdown]
# # Changing point transparency

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter", alpha=0.4)

# %% [markdown]
# # Scatter plots
# - each plot point is an independent observation

# %% [markdown]
# # Line plots
# - each plot point represents the same "thing", typically tracked over time

# %%
mpg = sns.load_dataset("mpg")

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# # Multiple observations per x-value

# %%
sns.relplot(x="model_year", y="mpg", data=mpg, kind="scatter")

# %%
sns.relplot(x="model_year", y="mpg", data=mpg, kind="line")

# %% [markdown]
# # Replacing Confidence Interval with Standard Deviation

# %%
sns.relplot(x="model_year", y="mpg", data=mpg, kind="line", ci=None)

# %%
sns.relplot(x="model_year", y="mpg", data=mpg, kind="line", ci="sd")

# %% [markdown]
# # Creating subgroups for country of origin

# %%
sns.relplot(x="model_year", y="mpg", data=mpg, kind="line", style="origin", hue="origin", ci=None)

# %% [markdown]
# # Adding markers and making each line have the same style

# %%
sns.relplot(x="model_year", y="mpg", data=mpg, kind="line", style="origin", hue="origin", ci=None, markers =True, dashes=False)

# %% [markdown]
# # Count plots and bar plots

# %% [markdown]
# Categorical plots
# - Examples: count plots, bar plots
# - Involve a categorical variable
# - Comparisons between the groups

# %% [markdown]
# # catplot()
# - Used to create categorical plots
# - Same advantages of relplot()
# - Easily create subplots with col= and row=

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x="day", data=tips)
plt.show()

# %%
sns.catplot(x="day", data=tips, kind="count")

# %% [markdown]
# # Bar plots
# - Display means of quantitative variable per category

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="bar")

# %% [markdown]
# # Confidence intervals
# - Lines show 95% confidence intervals for the mean
# - Shows uncertainty about our estimate
# - Assumes our data is a random sample

# %% [markdown]
# # Turning off confidence intervals

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="bar", ci=None)

# %% [markdown]
# # Changing the orientation

# %%
sns.catplot(x="total_bill", y="day", data=tips, kind="bar")

# %% [markdown]
# # Box plots
# - Show the distribution of quantitative data
# - See median, spread, skewness, and outliers
# - Facilitates comparisons between groups

# %%
sns.catplot(x="time", y="total_bill", data=tips, kind="box")

# %% [markdown]
# # Changing the order of categories

# %%
sns.catplot(x="time", y="total_bill", data=tips, kind="box", order=["Dinner", "Lunch"])

# %% [markdown]
# # Omitting the outliers using "sym"

# %%
sns.catplot(x="time", y="total_bill", data=tips, kind="box", order=["Dinner", "Lunch"], sym="")

# %% [markdown]
# # Chaging the whiskers using "whis"
# - Be default, the whiskers extend to 1,5* the interquartile range
# - Make them extend to 2.0 * IQR: whis=2.0
# - Show the 5th and 95th percentiles: whis=[5, 95]
# - Show min and max values: whis =[0, 100]

# %%
sns.catplot(x="time", y="total_bill", data=tips, kind="box",whis=[0, 100])

# %% [markdown]
# # Point plots
# - Points show mean of quantitative variable
# - Vertical lines show 95% confidence intervals

# %% [markdown]
# # Point plots vs. line plots
# Both show:
# - mean of quantitative variable
# - 95% confidence intervals for the mean
#
# Differences:
# - Line plot has quantitative variable (usually time) on x-axis
# - Point plot has categorical variable on x-axis

# %%
sns.catplot(x="smoker", y="total_bill", data=tips, kind="point")

# %% [markdown]
# # Displaying the median

# %%
from numpy import median
sns.catplot(x="smoker", y="total_bill", data=tips, kind="point", estimator=median)

# %% [markdown]
# # Customizing the confidence intervals

# %%
sns.catplot(x="smoker", y="total_bill", data=tips, kind="point", capsize=0.2)

# %% [markdown]
# # Turning off confidence intervals

# %%
sns.catplot(x="smoker", y="total_bill", data=tips, kind="point", ci=None)

# %% [markdown]
# # Disconnecting the points

# %%
sns.catplot(x="smoker", y="total_bill", data=tips, kind="point", join=False)

# %% [markdown]
# # Changing plot style and colors
# - Personal preferences
# - Improve readability
# - Guide interpretation

# %% [markdown]
# # Changing the figure style
# - Figure style includes background and axes
# - Present options: "white", "dark", "whitegrid", "darkgrid", "ticks"
# - sns.set_style()

# %%
sns.set_style("whitegrid")
sns.catplot(x="smoker", y="total_bill", data=tips, kind="point", capsize=0.2)

# %%
sns.set_style("darkgrid")
sns.catplot(x="smoker", y="total_bill", data=tips, kind="point", capsize=0.2)

# %%
sns.set_style("ticks")
sns.catplot(x="smoker", y="total_bill", data=tips, kind="point", capsize=0.2)

# %% [markdown]
# # Style and palette
# - Diverging palettes: "RdBu", "PRGn", "RdBu_r", "PRGn_r"

# %%
sns.set_palette("PRGn")
sns.catplot(x="day", y="total_bill", data=tips, kind="bar", ci=None)

# %%
sns.set_palette("PRGn_r")
sns.catplot(x="day", y="total_bill", data=tips, kind="bar", ci=None)

# %%
sns.set_palette("RdBu_r")
sns.catplot(x="day", y="total_bill", data=tips, kind="bar", ci=None)

# %%
sns.set_palette("RdBu")
sns.catplot(x="day", y="total_bill", data=tips, kind="bar", ci=None)

# %% [markdown]
# # Sequential palettes
# - "Greys", "Blues", "PuRd", "GnBu"

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter", size="size", hue="size")

# %% [markdown]
# # Changing the scale
# - Figure "context" changes the scale of the plot elements and labels
# - sns.set_context()
# - Smallest to largest: "paper", "notebook", "talk", "poster"

# %%
sns.relplot(x="total_bill", y ="tip", data=tips, kind="scatter", size="size", hue="size")

# %%
sns.set_context("poster")
sns.catplot(x="smoker", y="total_bill", data=tips, kind="point", capsize=0.2)

# %%
sns.set_context("paper")
sns.violinplot(x="day", y="total_bill", hue="smoker", data=tips, palette="Set2")

# %%
sns.lmplot(x='total_bill', y='tip', hue='time', data=tips, palette="Set2")

# %%
tips.corr(method='pearson')
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.set_context("notebook")
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
#tip_hist = tips['tip'].hist()

# %%
#tips_fig = tip_hist.get_figure()

# %%
tips_hist = tips.hist()

# %%
pd.scatter_matrix(tips, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# C:\Users\kildu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000206A954A438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000206A9585B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000206A95B25C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000206A95D7FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000206A9605A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000206A9605AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000206A965BFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000206A9687A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000206A96B5518>]],
#       dtype=object)
